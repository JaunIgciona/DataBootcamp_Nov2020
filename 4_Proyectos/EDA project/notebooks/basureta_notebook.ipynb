# %%
import pandas as pd 
import numpy as np 
import os
import sys
import datetime as dt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
root_project = os.path.dirname(os.getcwd())
sys.path.append(root_project)
movies_df_pkl_dir = root_project + '/resources/movies_df.pkl'
movies_pkl_df = pd.read_pickle(movies_df_pkl_dir)
movies_df = movies_pkl_df.copy()

countries_expanded_pkl_dir = root_project + '/resources/prod_countries_expanded.pkl'
countries_pkl_df = pd.read_pickle(countries_expanded_pkl_dir)
countries_df = countries_pkl_df.copy()

genre_expanded_pkl_dir = root_project + '/resources/genre_df_expanded.pkl'
genre_pkl_df = pd.read_pickle(genre_expanded_pkl_dir)
genre_expand_df = genre_pkl_df.copy()

# %%
import src.utils.visualization_tb as vis

# %%
sns.set()
msno.bar(movies_df)
# Out:
# <AxesSubplot:>

# %%
vis.column_pie(movies_df, 'original_language', 6)

# %%
vis.column_pie(countries_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-cda8a237a762> in <module>
# ----> 1 vis.column_pie(countries_df, 7)
#
# d:\Users\Juan\Documents\TheBridge\3. Git\Git_DataScience_JaunIgciona\DataBootcamp_Nov2020\4. Proyectos\EDA project\src\utils\visualization_tb.py in column_pie(dataset, column, n_to_show)
#      18
#      19     if column:
# ---> 20         ordered_by_col = dataset.groupby(f'{column}')[f'{column}'].count().sort_values(ascending=False)
#      21     else:
#      22         ordered_by_col = dataset.count().sort_values(ascending=False)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6513         axis = self._get_axis_number(axis)
#    6514
# -> 6515         return DataFrameGroupBy(
#    6516             obj=self,
# ...

# %%
vis.col_time_series(movies_df, 'release_date', 'Y', 'count', colour=5)

# %%
vis.count_bar(dataset=genre_expand_df)

# %%
X = np.linspace(0,5,100)
Y1 = X + 2*np.random.random(X.shape)
Y2 = X**2 + np.random.random(X.shape)

fig, ax = plt.subplots()
ax.plot(X,Y1,'o')
ax.plot(X,Y2,'x')

# %%
fig, ax = plt.subplots()
ax.vis.col_time_series(movies_df, 'budget', 'Y', colour=0)
ax.vis.col_time_series(movies_df, 'revenue', 'Y', colour=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-892036b6081a> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.vis.col_time_series(movies_df, 'budget', 'Y', colour=0)
#       3 ax.vis.col_time_series(movies_df, 'revenue', 'Y', colour=1)
#
# AttributeError: 'AxesSubplot' object has no attribute 'vis'

# %%
vis.without_0_hist(movies_df, 'revenue', 18)

# %%
vis.log_hist(movies_df, column='revenue', bin=18, without_0s=True, colour=2)

# %%
sns.set(palette='husl')

# %%
fig1 = sns.kdeplot(movies_df.runtime, fill=True)
vis.label_fig(xlab='runtime (mins)')
#sns.rugplot(movies_df.runtime)
#plt.savefig(root_project + '//reports//density_runtime.jpg')
#vis.save_repo('densityRuntime')

# %%
plt.hist(movies_df.vote_average)

# %%
plt.figure(figsize=(8,5))
vis.dense_plot(serie=movies_df.runtime)

# %%
def
